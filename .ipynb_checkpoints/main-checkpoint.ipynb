# %%
# import libraries
import yfinance as yf
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_score

# %%
# Draw S&P500 index data and query them

sp500 = yf.Ticker("^GSPC")
sp500 = sp500.history(period="max")

# %%
# Display data

sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2024-01-31 00:00:00-05:00  4899.189941  4906.750000  4845.149902  4845.649902
# 2024-02-01 00:00:00-05:00  4861.109863  4906.970215  4853.520020  4906.189941
# 2024-02-02 00:00:00-05:00  4916.060059  4975.290039  4907.990234  4958.609863
# 2024-02-05 00:00:00-05:00  4957.189941  4957.189941  4918.089844  4942.810059
# 2024-02-06 00:00:00-05:00  4950.160156  4957.770020  4934.879883  4954.229980
#
#                                Volume  Dividends  Stock Splits
# Date
# 1927-12-30 00:00:00-05:00           0        0.0           0.0
# 1928-01-03 00:00:00-05:00           0        0.0           0.0
# 1928-01-04 00:00:00-05:00           0        0.0           0.0
# 1928-01-05 00:00:00-05:00           0        0.0           0.0
# 1928-01-06 00:00:00-05:00           0        0.0           0.0
# ...                               ...        ...           ...
# 2024-01-31 00:00:00-05:00  4696120000        0.0           0.0
# 2024-02-01 00:00:00-05:00  4386090000        0.0           0.0
# 2024-02-02 00:00:00-05:00  3974350000        0.0           0.0
# 2024-02-05 00:00:00-05:00  4023640000        0.0           0.0
# 2024-02-06 00:00:00-05:00  2477503000        0.0           0.0
#
# [24140 rows x 7 columns]

# %%
# Changing index to desired format
sp500.index = pd.to_datetime(sp500.index.date)
sp500
# Out:
#                    Open         High          Low        Close      Volume  \
# 1927-12-30    17.660000    17.660000    17.660000    17.660000           0
# 1928-01-03    17.760000    17.760000    17.760000    17.760000           0
# 1928-01-04    17.719999    17.719999    17.719999    17.719999           0
# 1928-01-05    17.549999    17.549999    17.549999    17.549999           0
# 1928-01-06    17.660000    17.660000    17.660000    17.660000           0
# ...                 ...          ...          ...          ...         ...
# 2024-01-31  4899.189941  4906.750000  4845.149902  4845.649902  4696120000
# 2024-02-01  4861.109863  4906.970215  4853.520020  4906.189941  4386090000
# 2024-02-02  4916.060059  4975.290039  4907.990234  4958.609863  3974350000
# 2024-02-05  4957.189941  4957.189941  4918.089844  4942.810059  4023640000
# 2024-02-06  4950.160156  4957.770020  4934.879883  4954.229980  2477503000
#
#             Dividends  Stock Splits
# 1927-12-30        0.0           0.0
# 1928-01-03        0.0           0.0
# 1928-01-04        0.0           0.0
# 1928-01-05        0.0           0.0
# 1928-01-06        0.0           0.0
# ...               ...           ...
# 2024-01-31        0.0           0.0
# 2024-02-01        0.0           0.0
# 2024-02-02        0.0           0.0
# 2024-02-05        0.0           0.0
# 2024-02-06        0.0           0.0
#
# [24140 rows x 7 columns]

# %%
# Plot the data on closing price
sp500.plot.line(y = 'Close')
# Out:
# <Axes: >

# %%
# Retaining the data requied and dropping the others
sp500 = sp500[['Open', 'High', 'Low', 'Close', 'Volume']]
sp500
# Out:
#                    Open         High          Low        Close      Volume
# 1927-12-30    17.660000    17.660000    17.660000    17.660000           0
# 1928-01-03    17.760000    17.760000    17.760000    17.760000           0
# 1928-01-04    17.719999    17.719999    17.719999    17.719999           0
# 1928-01-05    17.549999    17.549999    17.549999    17.549999           0
# 1928-01-06    17.660000    17.660000    17.660000    17.660000           0
# ...                 ...          ...          ...          ...         ...
# 2024-01-31  4899.189941  4906.750000  4845.149902  4845.649902  4696120000
# 2024-02-01  4861.109863  4906.970215  4853.520020  4906.189941  4386090000
# 2024-02-02  4916.060059  4975.290039  4907.990234  4958.609863  3974350000
# 2024-02-05  4957.189941  4957.189941  4918.089844  4942.810059  4023640000
# 2024-02-06  4950.160156  4957.770020  4934.879883  4954.229980  2477503000
#
# [24140 rows x 5 columns]

# %%
# Create column for the next day

sp500['Next Day'] = sp500['Close'].shift(-1)
sp500.head()
# Out:
# C:\Users\vishn\AppData\Local\Temp\ipykernel_20788\2371682445.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sp500['Next Day'] = sp500['Close'].shift(-1)
#                  Open       High        Low      Close  Volume   Next Day
# 1927-12-30  17.660000  17.660000  17.660000  17.660000       0  17.760000
# 1928-01-03  17.760000  17.760000  17.760000  17.760000       0  17.719999
# 1928-01-04  17.719999  17.719999  17.719999  17.719999       0  17.549999
# 1928-01-05  17.549999  17.549999  17.549999  17.549999       0  17.660000
# 1928-01-06  17.660000  17.660000  17.660000  17.660000       0  17.500000

# %%
# Set target value for machine learning


# sp500['Target'] = (sp500['Next Day'] > sp500['Close']).astype(int)
sp500['Target'] = np.where(sp500['Next Day'] > sp500['Close'], 1, 0)
sp500
# Out:
#                    Open         High          Low        Close      Volume  \
# 1927-12-30    17.660000    17.660000    17.660000    17.660000           0
# 1928-01-03    17.760000    17.760000    17.760000    17.760000           0
# 1928-01-04    17.719999    17.719999    17.719999    17.719999           0
# 1928-01-05    17.549999    17.549999    17.549999    17.549999           0
# 1928-01-06    17.660000    17.660000    17.660000    17.660000           0
# ...                 ...          ...          ...          ...         ...
# 2024-01-31  4899.189941  4906.750000  4845.149902  4845.649902  4696120000
# 2024-02-01  4861.109863  4906.970215  4853.520020  4906.189941  4386090000
# 2024-02-02  4916.060059  4975.290039  4907.990234  4958.609863  3974350000
# 2024-02-05  4957.189941  4957.189941  4918.089844  4942.810059  4023640000
# 2024-02-06  4950.160156  4957.770020  4934.879883  4954.229980  2477503000
#
#                Next Day  Target
# 1927-12-30    17.760000       1
# 1928-01-03    17.719999       0
# 1928-01-04    17.549999       0
# 1928-01-05    17.660000       1
# 1928-01-06    17.500000       0
# ...                 ...     ...
# 2024-01-31  4906.189941       1
# 2024-02-01  4958.609863       1
# 2024-02-02  4942.810059       0
# 2024-02-05  4954.229980       1
# 2024-02-06          NaN       0
#
# [24140 rows x 7 columns]

# %%
# Slice data since 1980 till present
sp500 = sp500.loc['1980-01-01':].copy()
sp500.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Next Day', 'Target'], dtype='object')

# %%
# Train the machine learning model with test and train data

model = RandomForestClassifier(n_estimators = 200, random_state = 1)

train = sp500.iloc[:-100]
test = sp500.iloc[-100:]


predictors = ['Open', 'High', 'Low', 'Close', 'Volume']
model.fit(train[predictors], train['Target'] )
# Out:
# KeyboardInterrupt

# %%
# Make predicctions with the model
pred = model.predict(test[predictors])
pred = pd.Series(pred, index = test.index)
pred

# %%
# Calculate precision score
precision_score(test['Target'], pred)
# Out:
# 0.5384615384615384

# %%
# Combine the target and prediction of test data for plotting

test_pred_target = pd.concat([test['Target'], pred], axis=1)

test_pred_target.plot()
# Out:
# <Axes: >

# %%
# Create function to make predictions with machine learning models

def prediction(train, test, predictors, model):
    model.fit(train[predictors], train['Target'])
    pred = model.predict(test[predictors])
    pred = pd.Series(pred, index = test.index, name = 'pred')
    combined_result = pd.concat([test['Target'], pred], axis = 1)
    return combined_result

# %%
# Create function to backtest the model

def backtest(data, model, predictors, start = 2500, step = 250):
    predictions_df = []
    
    for i in range(2500, data.shape[0], 250):
        X = data.iloc[0:i].copy()
        y = data.iloc[i:(i+step)].copy()
        pred = prediction(X, y, predictors, model)
        predictions_df.append(pred)
        
    return pd.concat(predictions_df)

# %%
# Conduct back testing through backtesting

predictions = backtest(sp500, model, predictors)

# %%
# Evaluate the precision score

precision_score(predictions['Target'], predictions['pred'])
